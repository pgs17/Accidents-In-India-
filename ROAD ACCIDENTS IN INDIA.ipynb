# %% [markdown]
# # ANALYSIS OF  ROAD ACCIDENTS IN INDIA DURING 2014 and 2016

# %%
#Importing Libraries Required
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Getting Datasets From Kaggle
# !pip install opendatasets --upgrade --quiet

# %%
sns.set()

# %%
import os
import opendatasets as od
DATA_SET_URL='https://www.kaggle.com/datasets/thedevastator/state-ut-wise-road-accidents-due-to-driver-viola'
od.download(DATA_SET_URL)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: pgsgo17
# Your Kaggle Key: ········
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 1.72k/1.72k [00:00<00:00, 204kB/s]

# %%
accidents_df=pd.read_csv(r'state-ut-wise-road-accidents-due-to-driver-viola\driverresponse.csv')

# %%
accidents_df.head(10)
# Out:
#    index  sno            stateut     region  regionid  alcintake2014  \
# 0      0    1     Andhra Pradesh      south         2            594
# 1      1    2  Arunachal Pradesh  northeast         5             11
# 2      2    3              Assam  northeast         5            613
# 3      3    4              Bihar      north         1           1680
# 4      4    5       Chhattisgarh     centre         9            335
# 5      5    6                Goa       west         4              9
# 6      6    7            Gujarat       west         4             42
# 7      7    8            Haryana      north         1           1095
# 8      8    9   Himachal Pradesh      north         1             74
# 9      9   10    Jammu & Kashmir      north         1            388
#
#    overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 0        12747.0             507              328            668  ...
# ...

# %%
accidents_df.columns
# Out:
# Index(['index', 'sno', 'stateut', 'region', 'regionid', 'alcintake2014',
#        'overspeed2014', 'overtaking2014', 'lanejumping2014', 'wrongside2014',
#        'signalavoid2014', 'asleep2014', 'othercause2014', 'alcintake2016',
#        'overspeed2016', 'signalavoid2016', 'wrongside2016', 'lanejumping2016',
#        'overtaking2016', 'asleep2016', 'othercause2016'],
#       dtype='object')

# %%
accidents_df.head(10)
# Out:
#    index  sno            stateut     region  regionid  alcintake2014  \
# 0      0    1     Andhra Pradesh      south         2            594
# 1      1    2  Arunachal Pradesh  northeast         5             11
# 2      2    3              Assam  northeast         5            613
# 3      3    4              Bihar      north         1           1680
# 4      4    5       Chhattisgarh     centre         9            335
# 5      5    6                Goa       west         4              9
# 6      6    7            Gujarat       west         4             42
# 7      7    8            Haryana      north         1           1095
# 8      8    9   Himachal Pradesh      north         1             74
# 9      9   10    Jammu & Kashmir      north         1            388
#
#    overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 0        12747.0             507              328            668  ...
# ...

# %%
accidents_df.rename({'stateut':'State', 'region':'Region'},axis=1,inplace=True)

# %%
accidents_df.head()
# Out:
#    index  sno              State     Region  regionid  alcintake2014  \
# 0      0    1     Andhra Pradesh      south         2            594
# 1      1    2  Arunachal Pradesh  northeast         5             11
# 2      2    3              Assam  northeast         5            613
# 3      3    4              Bihar      north         1           1680
# 4      4    5       Chhattisgarh     centre         9            335
#
#    overspeed2014  overtaking2014  lanejumping2014  wrongside2014  ...  \
# 0        12747.0             507              328            668  ...
# 1           16.0               0                0              0  ...
# 2         4596.0             129              104            156  ...
# 3         1496.0             278              236            308  ...
# 4         6720.0             188              313            266  ...
#
#    asleep2014  othercause2014  alcintake2016  overspeed2016  signalavoid2016  \
# ...

# %%
accidents_df.describe()
# Out:
#            index        sno   regionid  alcintake2014  overspeed2014  \
# count  36.000000  36.000000  36.000000      36.000000      35.000000
# mean   17.500000  18.500000   4.000000     525.444444    5950.600000
# std    10.535654  10.535654   2.746426     767.133866    8677.731983
# min     0.000000   1.000000   1.000000       0.000000       0.000000
# 25%     8.750000   9.750000   1.750000      11.750000      72.500000
# 50%    17.500000  18.500000   4.000000      82.500000    2561.000000
# 75%    26.250000  27.250000   5.000000     706.500000    6493.000000
# max    35.000000  36.000000   9.000000    3540.000000   29790.000000
#
#        overtaking2014  lanejumping2014  wrongside2014  signalavoid2014  \
# count       36.000000        36.000000      36.000000        36.000000
# mean       312.833333       283.361111     302.000000        37.000000
# std        514.513279       462.370115     389.184642        81.196411
# ...

# %%
accidents_df.info()
# We can see one null is present in OverSpeed 2014 Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            36 non-null     int64
#  1   sno              36 non-null     int64
#  2   State            36 non-null     object
#  3   Region           36 non-null     object
#  4   regionid         36 non-null     int64
#  5   alcintake2014    36 non-null     int64
#  6   overspeed2014    35 non-null     float64
#  7   overtaking2014   36 non-null     int64
#  8   lanejumping2014  36 non-null     int64
#  9   wrongside2014    36 non-null     int64
#  10  signalavoid2014  36 non-null     int64
#  11  asleep2014       36 non-null     int64
#  12  othercause2014   36 non-null     int64
#  13  alcintake2016    36 non-null     int64
#  14  overspeed2016    36 non-null     int64
#  15  signalavoid2016  36 non-null     int64
#  16  wrongside2016    36 non-null     int64
# ...

# %%
# drop the Coloumns Not required
accidents_df.drop(['index', 'sno'],axis=1, inplace=True)

# %%
accidents_df
# Out:
#                 State     Region  regionid  alcintake2014  overspeed2014  \
# 0      Andhra Pradesh      south         2            594        12747.0
# 1   Arunachal Pradesh  northeast         5             11           16.0
# 2               Assam  northeast         5            613         4596.0
# 3               Bihar      north         1           1680         1496.0
# 4        Chhattisgarh     centre         9            335         6720.0
# 5                 Goa       west         4              9         3148.0
# 6             Gujarat       west         4             42        13752.0
# 7             Haryana      north         1           1095         4185.0
# 8    Himachal Pradesh      north         1             74         2763.0
# 9     Jammu & Kashmir      north         1            388         2859.0
# 10          Jharkhand     centre         9            611         1627.0
# 11          Karnataka      south         2           2207        23370.0
# ...

# %%
accidents_df.fillna('0',axis=1, inplace=True)

# %%
accidents_df
# Out:
#                 State     Region regionid alcintake2014 overspeed2014  \
# 0      Andhra Pradesh      south        2           594       12747.0
# 1   Arunachal Pradesh  northeast        5            11          16.0
# 2               Assam  northeast        5           613        4596.0
# 3               Bihar      north        1          1680        1496.0
# 4        Chhattisgarh     centre        9           335        6720.0
# 5                 Goa       west        4             9        3148.0
# 6             Gujarat       west        4            42       13752.0
# 7             Haryana      north        1          1095        4185.0
# 8    Himachal Pradesh      north        1            74        2763.0
# 9     Jammu & Kashmir      north        1           388        2859.0
# 10          Jharkhand     centre        9           611        1627.0
# 11          Karnataka      south        2          2207       23370.0
# ...

# %%
accidents_df['overspeed2014'].astype(np.int32)
# Out:
# 0     12747
# 1        16
# 2      4596
# 3      1496
# 4      6720
# 5      3148
# 6     13752
# 7      4185
# 8      2763
# 9      2859
# 10     1627
# 11    23370
# 12    20611
# 13    20967
# 14    29790
# 15        0
# 16       40
# 17       48
# 18       51
# 19     3699
# 20     2253
# 21    11395
# 22       28
# 23    28804
# 24     6266
# 25      499
# 26       94
# 27     2561
# 28     3339
# 29       94
# 30      160
# 31       21
# 32       21
# 33        0
# 34        1
# 35      250
# Name: overspeed2014, dtype: int32

# %%
accidents_df['State'].unique 
# 36 states are there.So no State is missing
# Out:
# <bound method Series.unique of 0        Andhra Pradesh
# 1     Arunachal Pradesh
# 2                 Assam
# 3                 Bihar
# 4          Chhattisgarh
# 5                   Goa
# 6               Gujarat
# 7               Haryana
# 8      Himachal Pradesh
# 9       Jammu & Kashmir
# 10            Jharkhand
# 11            Karnataka
# 12               Kerala
# 13       Madhya Pradesh
# 14          Maharashtra
# 15              Manipur
# 16            Meghalaya
# 17              Mizoram
# 18             Nagaland
# 19               Orissa
# 20               Punjab
# 21            Rajasthan
# 22               Sikkim
# 23           Tamil Nadu
# 24            Telangana
# 25              Tripura
# 26          Uttarakhand
# 27        Uttar Pradesh
# 28          West Bengal
# 29        A & N Islands
# 30           Chandigarh
# 31         D & N Haveli
# 32          Daman & Diu
# 33                Delhi
# 34          Lakshadweep
# 35           Puducherry
# Name: State, dtype: object>

# %% [markdown]
# #### 1. No State is missing from the data
# #### 2. All Nan values are Replaced with '0' AND not analyising them
# #### 3. Dropped two coloumns sno and index

# %%
accidents_df.columns
# Out:
# Index(['State', 'Region', 'regionid', 'alcintake2014', 'overspeed2014',
#        'overtaking2014', 'lanejumping2014', 'wrongside2014', 'signalavoid2014',
#        'asleep2014', 'othercause2014', 'alcintake2016', 'overspeed2016',
#        'signalavoid2016', 'wrongside2016', 'lanejumping2016', 'overtaking2016',
#        'asleep2016', 'othercause2016'],
#       dtype='object')

# %% [markdown]
# # ANALYSIS OF 2014 DATA
# ### ANALYIZING ACCIDENTS CAUSED DUE TO ALCOHOL INTAKE, OVERTAKING  ,LANEJUMPING , ASLEEP, WRONG SIDE AND SIGNAL AVOID
#
# #### Things to analyse is 1. Find States where accidents are  maximum due to the reasons involved and also find states where accidents due to alcohol intake is greater than 300

# %%
df1= accidents_df.groupby(['State','Region','regionid'])[['alcintake2014','overspeed2014','overtaking2014','lanejumping2014',
                                                         'wrongside2014','signalavoid2014','asleep2014','othercause2014']].sum()

# %%
df1['overspeed2014'].astype(np.int32)
# Out:
# State              Region     regionid
# A & N Islands      southeast  7              94
# Andhra Pradesh     south      2           12747
# Arunachal Pradesh  northeast  5              16
# Assam              northeast  5            4596
# Bihar              north      1            1496
# Chandigarh         north      1             160
# Chhattisgarh       centre     9            6720
# D & N Haveli       west       4              21
# Daman & Diu        west       4              21
# Delhi              north      1               0
# Goa                west       4            3148
# Gujarat            west       4           13752
# Haryana            north      1            4185
# Himachal Pradesh   north      1            2763
# Jammu & Kashmir    north      1            2859
# Jharkhand          centre     9            1627
# Karnataka          south      2           23370
# Kerala             south      2           20611
# Lakshadweep        southwest  8               1
# ...

# %%
df1
# Out:
#                                       alcintake2014 overspeed2014  \
# State             Region    regionid
# A & N Islands     southeast 7                    25          94.0
# Andhra Pradesh    south     2                   594       12747.0
# Arunachal Pradesh northeast 5                    11          16.0
# Assam             northeast 5                   613        4596.0
# Bihar             north     1                  1680        1496.0
# Chandigarh        north     1                    11         160.0
# Chhattisgarh      centre    9                   335        6720.0
# D & N Haveli      west      4                     1          21.0
# Daman & Diu       west      4                     0          21.0
# Delhi             north     1                    51             0
# Goa               west      4                     9        3148.0
# Gujarat           west      4                    42       13752.0
# Haryana           north     1                  1095        4185.0
# ...

# %%
df1[['alcintake2014','overtaking2014','lanejumping2014','wrongside2014','signalavoid2014','asleep2014','othercause2014']].sum()
# Out:
# alcintake2014      18916
# overtaking2014     11262
# lanejumping2014    10201
# wrongside2014      10872
# signalavoid2014     1332
# asleep2014          3313
# othercause2014     36286
# dtype: int64

# %% [markdown]
# #### In whole India the total number of accidents caused due to various reasons in 2014 are
# #### alcintake :18916
# #### overtaking:11262
# #### lanejumping:10201
# #### wrongside :10872
# #### signalavoid:1332
# #### asleep : 3313
# #### othercause:36286

# %%
sns.relplot(x='alcintake2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO ALCOHOL INTAKE 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO ALCOHOL INTAKE 2014')

# %%
sns.relplot(x='overspeed2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO OVERSPEED IN 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO OVERSPEED IN 2014')

# %%
sns.relplot(x='overtaking2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO OVERTAKING 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO OVERTAKING 2014')

# %%
sns.relplot(x='lanejumping2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO LANE JUMPING 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO LANE JUMPING 2014')

# %%
sns.relplot(x='asleep2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO ASLEEP 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO ASLEEP 2014')

# %%
sns.relplot(x='wrongside2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO WRONG SIDE 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO WRONG SIDE 2014')

# %%
sns.relplot(x='signalavoid2014',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO SIGNAL AVOID 2014')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO SIGNAL AVOID 2014')

# %%
df0=accidents_df[accidents_df['alcintake2014']>300]
len(df0['State'])
# Out:
# 17

# %%
print("STATES IN WHICH ACCIDENTS DUE TO ALCHOL INTAKE IS GREATER THAN 300 IN 2014")
df0['State']
# Out:
# STATES IN WHICH ACCIDENTS DUE TO ALCHOL INTAKE IS GREATER THAN 300 IN 2014
# 0      Andhra Pradesh
# 2               Assam
# 3               Bihar
# 4        Chhattisgarh
# 7             Haryana
# 9     Jammu & Kashmir
# 10          Jharkhand
# 11          Karnataka
# 13     Madhya Pradesh
# 14        Maharashtra
# 19             Orissa
# 20             Punjab
# 21          Rajasthan
# 23         Tamil Nadu
# 24          Telangana
# 26        Uttarakhand
# 27      Uttar Pradesh
# Name: State, dtype: object

# %% [markdown]
# ## Conclusion for 2014 data :
# #### STATE IN WHICH ACCIDENTS ARE MAXIMUM DUE TO  ALOCHOL INTAKE IS MADHYA PRADESH
# #### STATE IN WHICH ACCIDENTS ARE   MAXIMUM  DUE TO  OVERTAKING IS TAMIL NADU
# #### STATE IN WHICH ACCIDENTS ARE   MAXIMUM  DUE TO  JUMPING OF LANE IS TAMIL NADU
# #### STATE IN WHICH ACCIDENTS ARE   MAXIMUM DUE TO  FALLING ASLEEP IS KERELA
# #### STATE IN WHICH ACCIDENTS ARE  MAXIMUM  DUE TO  DRIVING IN WRONG SIDE IS TAMIL NADU
# #### STATE IN WHICH ACCIDENTS ARE  MAXIMUM DUE TO  SIGNAL AVOID IS TAMIL NADU
#
# #####  TAMIL NADU is the State where people mostly dont follow rules and regulations due to which accidents are high.So the police should take strict action and see that people are careful and accidents to be avoided
#
#
# ###### 17 states have accidents caused due to alcohol intake greater than 300

# %% [markdown]
# # ANALYSIS OF 2016 DATA
# ### ANALYIZING ACCIDENTS CAUSED DUE TO ALCOHOL INTAKE, OVERTAKING  ,LANEJUMPING , ASLEEP, WRONG SIDE AND SIGNAL AVOID
#
# #### Things to analyse is 1. Find States where accidents are  maximum due to the reasons involved and also find states where accidents due to alcohol intake and lane jumping is greater than 300 and 200 respectively

# %%
df2=accidents_df.groupby(['State','Region','regionid'])[['alcintake2016','overspeed2016','overtaking2016','lanejumping2016',
                                                         'wrongside2016','signalavoid2016','asleep2016','othercause2016']].sum()

# %%
df2
# Out:
#                                       alcintake2016  overspeed2016  \
# State             Region    regionid
# A & N Islands     southeast 7                    27            124
# Andhra Pradesh    south     2                   128          17286
# Arunachal Pradesh northeast 5                    15             45
# Assam             northeast 5                   352           3520
# Bihar             north     1                   593           2323
# Chandigarh        north     1                     9            380
# Chhattisgarh      centre    9                   145           6660
# D & N Haveli      west      4                     0              8
# Daman & Diu       west      4                     7             29
# Delhi             north     1                   164           1696
# Goa               west      4                     3           3883
# Gujarat           west      4                    64          13314
# ...

# %%
df2.info()
# NO NULL VALUES IN ANY COLOUMNS SO ANALYSE ALL COLOUMNS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 36 entries, ('A & N Islands', 'southeast', 7) to ('West Bengal', 'east', 3)
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   alcintake2016    36 non-null     int64
#  1   overspeed2016    36 non-null     int64
#  2   overtaking2016   36 non-null     int64
#  3   lanejumping2016  36 non-null     int64
#  4   wrongside2016    36 non-null     int64
#  5   signalavoid2016  36 non-null     int64
#  6   asleep2016       36 non-null     int64
#  7   othercause2016   36 non-null     int64
# dtypes: int64(8)
# memory usage: 2.9+ KB

# %%
df2.head()
# Out:
#                                       alcintake2016  overspeed2016  \
# State             Region    regionid
# A & N Islands     southeast 7                    27            124
# Andhra Pradesh    south     2                   128          17286
# Arunachal Pradesh northeast 5                    15             45
# Assam             northeast 5                   352           3520
# Bihar             north     1                   593           2323
#
#                                       overtaking2016  lanejumping2016  \
# State             Region    regionid
# A & N Islands     southeast 7                     15                0
# Andhra Pradesh    south     2                   1024              325
# Arunachal Pradesh northeast 5                      8               11
# Assam             northeast 5                    371              156
# Bihar             north     1                    573              156
#
# ...

# %%
df2[['alcintake2016','overspeed2016','overtaking2016','lanejumping2016','wrongside2016','signalavoid2016','asleep2016','othercause2016']].sum()
# Out:
# alcintake2016       14894
# overspeed2016      268341
# overtaking2016      29647
# lanejumping2016      8513
# wrongside2016       17654
# signalavoid2016      4491
# asleep2016           4552
# othercause2016      50530
# dtype: int64

# %% [markdown]
# #### In whole India the total number of accidents caused due to various reasons in 2016 are
# #### alcintake :14894
# #### overspeed: 268341
# #### overtaking : 29647
# #### lanejumping: 8513
# #### wrongside: 17654
# #### signalavoid: 4491
# #### asleep: 4552
# #### othercause:50530

# %%
sns.relplot(x='alcintake2016',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO ALCOHOL INTAKE 2016')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO ALCOHOL INTAKE 2016')

# %%
sns.relplot(x='overtaking2016',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO OVERTAKING 2016')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO OVERTAKING 2016')

# %%
sns.relplot(x='lanejumping2016',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO LANE JUMPING 2016')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO LANE JUMPING 2016')

# %%
sns.relplot(x='asleep2016',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO ASLEEP 2016')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO ASLEEP 2016')

# %%
sns.relplot(x='wrongside2016',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO WRONG SIDE 2016')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO WRONG SIDE 2016')

# %%
sns.relplot(x='signalavoid2016',y='State',data=accidents_df)
plt.title('ACCIDENTS DUE TO SIGNAL AVOID 2016')
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO SIGNAL AVOID 2016')

# %%
sns.relplot(x='overspeed2016',y='State',data=accidents_df)
plt.title("ACCIDENTS DUE TO OVERSPEEDING 2016")
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO OVERSPEEDING 2016')

# %%
d0=accidents_df[accidents_df['alcintake2016']>300]
len(d0['State'])
# Out:
# 12

# %%
d3=accidents_df[accidents_df['lanejumping2016']>200]
len(d3['State'])
# Out:
# 9

# %%
print("STATES WITH ACCIDENTS CAUSED DUE TO ALCOHOL INTAKE IS GREATER THAN 300 IN 2016")
print(d0['State'])
print("STATES IN WHICH ACCIDENTS CAUSED DUE TO LANE JUMPING IS GREATER THAN 200 IN 2016")
print(d3['State'])
# Out:
# STATES WITH ACCIDENTS CAUSED DUE TO ALCOHOL INTAKE IS GREATER THAN 300 IN 2016
# 2              Assam
# 3              Bihar
# 7            Haryana
# 10         Jharkhand
# 11         Karnataka
# 13    Madhya Pradesh
# 19            Orissa
# 20            Punjab
# 21         Rajasthan
# 23        Tamil Nadu
# 27     Uttar Pradesh
# 28       West Bengal
# Name: State, dtype: object
# STATES IN WHICH ACCIDENTS CAUSED DUE TO LANE JUMPING IS GREATER THAN 200 IN 2016
# 0     Andhra Pradesh
# 6            Gujarat
# 7            Haryana
# 11         Karnataka
# 13    Madhya Pradesh
# 14       Maharashtra
# 21         Rajasthan
# 23        Tamil Nadu
# 27     Uttar Pradesh
# Name: State, dtype: object

# %% [markdown]
# ## Conclusion for 2016 data :
# #### STATE IN WHICH ACCIDENTS ARE MAXIMUM DUE TO  ALOCHOL INTAKE IS UTTAR PRADESH
# #### STATE IN WHICH ACCIDENTS ARE   MAXIMUM  DUE TO  OVERTAKING IS TAMIL NADU
# #### STATE IN WHICH ACCIDENTS ARE   MAXIMUM  DUE TO  JUMPING OF LANE IS TAMIL NADU
# #### STATE IN WHICH ACCIDENTS ARE   MAXIMUM DUE TO  FALLING ASLEEP IS UTTAR PRADESH
# #### STATE IN WHICH ACCIDENTS ARE  MAXIMUM  DUE TO  DRIVING IN WRONG SIDE IS TAMIL NADU in close with UTTAR PRADESH
# #### STATE IN WHICH ACCIDENTS ARE  MAXIMUM DUE TO  SIGNAL AVOID IS TAMIL NADU
# #### STATE IN WHICH ACCIDENTS ARE MAXIMUM DUE TO OVERSPEEDING IS TAMIL NADU
#
# #### 12 states have accidents caused due to alcohol intake greater than 300 and 9 states have accidents caused due to lane jumping greater than 200

# %%
sns.relplot(x='othercause2014',y='State', data=accidents_df)
plt.title("ACCIDENTS DUE TO OTHER CAUSES IN 2014")
sns.relplot(x='othercause2016',y='State',data=accidents_df)
plt.title("ACCIDENTS DUE TO OTHER CAUSES IN 2016")
# Out:
# Text(0.5, 1.0, 'ACCIDENTS DUE TO OTHER CAUSES IN 2016')

# %% [markdown]
# # CONCLUSION :
#
# #### 1. TAMIL NADU IS THE STATE WHICH DOESNT FOLLOW ANY SORT OF TRAFFIC REGULATIONS AS MOST ACCIDENTS DUE TO VARIOUS REASONS ARE MAXIMUM FOUND IN TAMIL NADU
# #### 2. TO AVOID ACCIDENTS PEOPLE SHOULD BE CAREFUL WHILE DRIVING AND ALSO THE TRAFFIC POLICE SHOULD PUT THE CHECK ON DRIVERS
# #### 3. ALOCHOL INTAKE AND OVERSPEEDING WITH WRONG SIDE DRIVING HAVE BEEN THE MAJOR CAUSES OF ACCIDENTS ALL OVER INDIA
